# %% [markdown]
# ## Pandas: 3

# %%
import pandas as pd

# %%
df=pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass
# 0              1         0       3  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp
# 0                              Braund, Mr. Owen Harris    male  22.0      1  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df[['Name']][2:12]
# Out:
#                                                  Name
# 2                              Heikkinen, Miss. Laina
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                            Allen, Mr. William Henry
# 5                                    Moran, Mr. James
# 6                             McCarthy, Mr. Timothy J
# 7                      Palsson, Master. Gosta Leonard
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                 Nasser, Mrs. Nicholas (Adele Achem)
# 10                    Sandstrom, Miss. Marguerite Rut
# 11                           Bonnell, Miss. Elizabeth

# %%
len(df)
# Out:
# 891

# %%
l=['a','b','c','d','e','f','g']

# %%
l
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f', 'g']

# %%
pd.Series(l)
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# 4    e
# 5    f
# 6    g
# dtype: object

# %%
df['Name'][2:7]
# Out:
# 2                          Heikkinen, Miss. Laina
# 3    Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                        Allen, Mr. William Henry
# 5                                Moran, Mr. James
# 6                         McCarthy, Mr. Timothy J
# Name: Name, dtype: object

# %%
s=pd.Series(list(df['Name'][2:7]),index=['a','b','c','d','e'])

# %%
s
# Out:
# a                          Heikkinen, Miss. Laina
# b    Futrelle, Mrs. Jacques Heath (Lily May Peel)
# c                        Allen, Mr. William Henry
# d                                Moran, Mr. James
# e                         McCarthy, Mr. Timothy J
# dtype: object

# %%
s1=df['Name'][11:16]

# %%
s+s1
# Out:
# a     NaN
# b     NaN
# c     NaN
# d     NaN
# e     NaN
# 11    NaN
# 12    NaN
# 13    NaN
# 14    NaN
# 15    NaN
# dtype: object

# %%
pd.concat([s,s1])
# Out:
# a                           Heikkinen, Miss. Laina
# b     Futrelle, Mrs. Jacques Heath (Lily May Peel)
# c                         Allen, Mr. William Henry
# d                                 Moran, Mr. James
# e                          McCarthy, Mr. Timothy J
# 11                        Bonnell, Miss. Elizabeth
# 12                  Saundercock, Mr. William Henry
# 13                     Andersson, Mr. Anders Johan
# 14            Vestrom, Miss. Hulda Amanda Adolfina
# 15                Hewlett, Mrs. (Mary D Kingcome)
# dtype: object

# %%
df.drop('PassengerId',axis=1)
# Out:
#      Survived  Pclass                                               Name
# 0           0       3                            Braund, Mr. Owen Harris  \
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df.drop('PassengerId',axis=1,inplace=True)

# %%
df
# Out:
#      Survived  Pclass                                               Name
# 0           0       3                            Braund, Mr. Owen Harris  \
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df.drop(1)
# Out:
#      Survived  Pclass                                          Name     Sex
# 0           0       3                       Braund, Mr. Owen Harris    male  \
# 2           1       3                        Heikkinen, Miss. Laina  female
# 3           1       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4           0       3                      Allen, Mr. William Henry    male
# 5           0       3                              Moran, Mr. James    male
# ..        ...     ...                                           ...     ...
# 886         0       2                         Montvila, Rev. Juozas    male
# 887         1       1                  Graham, Miss. Margaret Edith  female
# 888         0       3      Johnston, Miss. Catherine Helen "Carrie"  female
# 889         1       1                         Behr, Mr. Karl Howell    male
# 890         0       3                           Dooley, Mr. Patrick    male
#
# ...

# %%
df.drop(1,inplace=True)

# %%
df
# Out:
#      Survived  Pclass                                          Name     Sex
# 0           0       3                       Braund, Mr. Owen Harris    male  \
# 2           1       3                        Heikkinen, Miss. Laina  female
# 3           1       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4           0       3                      Allen, Mr. William Henry    male
# 5           0       3                              Moran, Mr. James    male
# ..        ...     ...                                           ...     ...
# 886         0       2                         Montvila, Rev. Juozas    male
# 887         1       1                  Graham, Miss. Margaret Edith  female
# 888         0       3      Johnston, Miss. Catherine Helen "Carrie"  female
# 889         1       1                         Behr, Mr. Karl Howell    male
# 890         0       3                           Dooley, Mr. Patrick    male
#
# ...

# %%
df.set_index('Name',inplace=True)

# %%
df
# Out:
#                                               Survived  Pclass     Sex   Age
# Name
# Braund, Mr. Owen Harris                              0       3    male  22.0  \
# Heikkinen, Miss. Laina                               1       3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1  female  35.0
# Allen, Mr. William Henry                             0       3    male  35.0
# Moran, Mr. James                                     0       3    male   NaN
# ...                                                ...     ...     ...   ...
# Montvila, Rev. Juozas                                0       2    male  27.0
# Graham, Miss. Margaret Edith                         1       1  female  19.0
# Johnston, Miss. Catherine Helen "Carrie"             0       3  female   NaN
# Behr, Mr. Karl Howell                                1       1    male  26.0
# Dooley, Mr. Patrick                                  0       3    male  32.0
#
# ...

# %%
df.loc['Heikkinen, Miss. Laina']
# Out:
# Survived                   1
# Pclass                     3
# Sex                   female
# Age                     26.0
# SibSp                      0
# Parch                      0
# Ticket      STON/O2. 3101282
# Fare                   7.925
# Cabin                    NaN
# Embarked                   S
# Name: Heikkinen, Miss. Laina, dtype: object

# %%
df.iloc[1]
# Out:
# Survived                   1
# Pclass                     3
# Sex                   female
# Age                     26.0
# SibSp                      0
# Parch                      0
# Ticket      STON/O2. 3101282
# Fare                   7.925
# Cabin                    NaN
# Embarked                   S
# Name: Heikkinen, Miss. Laina, dtype: object

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#                                              Name  Survived  Pclass     Sex
# 0                         Braund, Mr. Owen Harris         0       3    male  \
# 1                          Heikkinen, Miss. Laina         1       3  female
# 2    Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1  female
# 3                        Allen, Mr. William Henry         0       3    male
# 4                                Moran, Mr. James         0       3    male
# ..                                            ...       ...     ...     ...
# 885                         Montvila, Rev. Juozas         0       2    male
# 886                  Graham, Miss. Margaret Edith         1       1  female
# 887      Johnston, Miss. Catherine Helen "Carrie"         0       3  female
# 888                         Behr, Mr. Karl Howell         1       1    male
# 889                           Dooley, Mr. Patrick         0       3    male
#
# ...

# %%
df.head()
# Out:
#                                            Name  Survived  Pclass     Sex
# 0                       Braund, Mr. Owen Harris         0       3    male  \
# 1                        Heikkinen, Miss. Laina         1       3  female
# 2  Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1  female
# 3                      Allen, Mr. William Henry         0       3    male
# 4                              Moran, Mr. James         0       3    male
#
#     Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 2  35.0      1      0            113803  53.1000  C123        S
# 3  35.0      0      0            373450   8.0500   NaN        S
# 4   NaN      0      0            330877   8.4583   NaN        Q

# %%
d={
    "key1":[2,3,4,5],
    "key2":[8,5,4,1],
    "key3":[9,4,1,2],
    "key4":[2,4,1,3],
    "key5":[7,5,1,4],
    "key6":[9,11,42,4],
}

# %%
pd.DataFrame(d)
# Out:
#    key1  key2  key3  key4  key5  key6
# 0     2     8     9     2     7     9
# 1     3     5     4     4     5    11
# 2     4     4     1     1     1    42
# 3     5     1     2     3     4     4

# %%
df2=pd.read_csv('taxonomy.csv')

# %%
df2.head()
# Out:
#   taxonomy_id                     name parent_id     parent_name
# 0         101                Emergency       NaN             NaN
# 1      101-01        Disaster Response       101       Emergency
# 2      101-02           Emergency Cash       101       Emergency
# 3   101-02-01        Help Pay for Food    101-02  Emergency Cash
# 4   101-02-02  Help Pay for Healthcare    101-02  Emergency Cash

# %%
#Handling Null Values
df2.dropna(inplace=True)

# %%
df2
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# 5     101-02-03          Help Pay for Housing    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [279 rows x 4 columns]

# %%
df2.reset_index(inplace=True)

# %%
df2
# Out:
#      index taxonomy_id                          name parent_id
# 0        1      101-01             Disaster Response       101  \
# 1        2      101-02                Emergency Cash       101
# 2        3   101-02-01             Help Pay for Food    101-02
# 3        4   101-02-02       Help Pay for Healthcare    101-02
# 4        5   101-02-03          Help Pay for Housing    101-02
# ..     ...         ...                           ...       ...
# 274    285   111-01-07              Workplace Rights    111-01
# 275    286      111-02                     Mediation       111
# 276    287      111-03                        Notary       111
# 277    288      111-04                Representation       111
# 278    289      111-05  Translation & Interpretation       111
#
#               parent_name
# 0               Emergency
# 1               Emergency
# 2          Emergency Cash
# 3          Emergency Cash
# 4          Emergency Cash
# ..                    ...
# ...

# %%
df2=pd.read_csv('taxonomy.csv')

# %%
df2
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df2
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df2.fillna('Gaurav')
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency    Gaurav                Gaurav
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df.head()
# Out:
#                                            Name  Survived  Pclass     Sex
# 0                       Braund, Mr. Owen Harris         0       3    male  \
# 1                        Heikkinen, Miss. Laina         1       3  female
# 2  Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1  female
# 3                      Allen, Mr. William Henry         0       3    male
# 4                              Moran, Mr. James         0       3    male
#
#     Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 2  35.0      1      0            113803  53.1000  C123        S
# 3  35.0      0      0            373450   8.0500   NaN        S
# 4   NaN      0      0            330877   8.4583   NaN        Q

# %%
df.groupby(['Survived']).sum()
# Out:
#                                                        Name  Pclass
# Survived
# 0         Braund, Mr. Owen HarrisAllen, Mr. William Henr...    1390  \
# 1         Heikkinen, Miss. LainaFutrelle, Mrs. Jacques H...     666
#
#                                                         Sex       Age  SibSp
# Survived
# 0         malemalemalemalemalemalemalefemalemalefemalema...  12985.50    304  \
# 1         femalefemalefemalefemalefemalefemalefemalemale...   8181.67    161
#
#           Parch                                             Ticket
# Survived
# 0           181  A/5 2117137345033087717463349909A/5. 215134708...  \
# 1           159  STON/O2. 3101282113803347742237736PP 954911378...
#
#                 Fare                                              Cabin
# Survived
# 0         12142.7199  E46C23 C25 C27B30C83F G73E31A5D26C110B58 B60D2...  \
# 1         16479.9461  C123G6C103D56A6B78D33C52B28F33C23 C25 C27D10 D...
#
# ...

# %%
df.groupby(['Sex']).sum()['Fare']
# Out:
# Sex
# female    13895.3795
# male      14727.2865
# Name: Fare, dtype: float64

# %%
df.groupby(['Pclass']).sum()['Fare']
# Out:
# Pclass
# 1    18106.1292
# 2     3801.8417
# 3     6714.6951
# Name: Fare, dtype: float64

# %%
df3=df.groupby(['Pclass']).sum()

# %%
df3
# Out:
#                                                      Name  Survived
# Pclass
# 1       Futrelle, Mrs. Jacques Heath (Lily May Peel)Mc...       135  \
# 2       Nasser, Mrs. Nicholas (Adele Achem)Hewlett, Mr...        87
# 3       Braund, Mr. Owen HarrisHeikkinen, Miss. LainaA...       119
#
#                                                       Sex      Age  SibSp
# Pclass
# 1       femalemalefemalemalemalemalefemalemalemalefema...  7073.42     89  \
# 2       femalefemalemalemalemalemalefemalefemalefemale...  5168.83     74
# 3       malefemalemalemalemalefemalefemalemalemalefema...  8924.92    302
#
#         Parch                                             Ticket        Fare
# Pclass
# 1          77  1138031746311378311378819950PC 17601PC 17569PC...  18106.1292  \
# 2          70  237736248706244373239865248698C.A. 2457911668S...   3801.8417
# 3         193  A/5 21171STON/O2. 3101282373450330877349909347...   6714.6951
#
# ...

# %%
df3
# Out:
#                                                      Name  Survived
# Pclass
# 1       Futrelle, Mrs. Jacques Heath (Lily May Peel)Mc...       135  \
# 2       Nasser, Mrs. Nicholas (Adele Achem)Hewlett, Mr...        87
# 3       Braund, Mr. Owen HarrisHeikkinen, Miss. LainaA...       119
#
#                                                       Sex      Age  SibSp
# Pclass
# 1       femalemalefemalemalemalemalefemalemalemalefema...  7073.42     89  \
# 2       femalefemalemalemalemalemalefemalefemalefemale...  5168.83     74
# 3       malefemalemalemalemalefemalefemalemalemalefema...  8924.92    302
#
#         Parch                                             Ticket        Fare
# Pclass
# 1          77  1138031746311378311378819950PC 17601PC 17569PC...  18106.1292  \
# 2          70  237736248706244373239865248698C.A. 2457911668S...   3801.8417
# 3         193  A/5 21171STON/O2. 3101282373450330877349909347...   6714.6951
#
# ...

# %%
df3.T
# Out:
# Pclass                                                    1
# Name      Futrelle, Mrs. Jacques Heath (Lily May Peel)Mc...  \
# Survived                                                135
# Sex       femalemalefemalemalemalemalefemalemalemalefema...
# Age                                                 7073.42
# SibSp                                                    89
# Parch                                                    77
# Ticket    1138031746311378311378819950PC 17601PC 17569PC...
# Fare                                             18106.1292
# Cabin     C123E46C103A6C23 C25 C27B78D33B30C52B28C83C23 ...
# Embarked  SSSSSCCCSCCSSCSSSCCSSCSSSCSCSSSCCSSCCCCCSSQSSC...
#
# Pclass                                                    2
# Name      Nasser, Mrs. Nicholas (Adele Achem)Hewlett, Mr...  \
# Survived                                                 87
# Sex       femalefemalemalemalemalemalefemalefemalefemale...
# Age                                                 5168.83
# ...

# %%
df3.transpose()
# Out:
# Pclass                                                    1
# Name      Futrelle, Mrs. Jacques Heath (Lily May Peel)Mc...  \
# Survived                                                135
# Sex       femalemalefemalemalemalemalefemalemalemalefema...
# Age                                                 7073.42
# SibSp                                                    89
# Parch                                                    77
# Ticket    1138031746311378311378819950PC 17601PC 17569PC...
# Fare                                             18106.1292
# Cabin     C123E46C103A6C23 C25 C27B78D33B30C52B28C83C23 ...
# Embarked  SSSSSCCCSCCSSCSSSCCSSCSSSCSCSSSCCSSCCCCCSSQSSC...
#
# Pclass                                                    2
# Name      Nasser, Mrs. Nicholas (Adele Achem)Hewlett, Mr...  \
# Survived                                                 87
# Sex       femalefemalemalemalemalemalefemalefemalefemale...
# Age                                                 5168.83
# ...

# %%
df.head()
# Out:
#                                            Name  Survived  Pclass     Sex
# 0                       Braund, Mr. Owen Harris         0       3    male  \
# 1                        Heikkinen, Miss. Laina         1       3  female
# 2  Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1  female
# 3                      Allen, Mr. William Henry         0       3    male
# 4                              Moran, Mr. James         0       3    male
#
#     Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 2  35.0      1      0            113803  53.1000  C123        S
# 3  35.0      0      0            373450   8.0500   NaN        S
# 4   NaN      0      0            330877   8.4583   NaN        Q

# %%
df4=df[['Name','Survived','Pclass']][0:5]

# %%
df4
# Out:
#                                            Name  Survived  Pclass
# 0                       Braund, Mr. Owen Harris         0       3
# 1                        Heikkinen, Miss. Laina         1       3
# 2  Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1
# 3                      Allen, Mr. William Henry         0       3
# 4                              Moran, Mr. James         0       3

# %%
df5=df[['Name','Survived','Pclass']][5:10]

# %%
df5
# Out:
#                                                 Name  Survived  Pclass
# 5                            McCarthy, Mr. Timothy J         0       1
# 6                     Palsson, Master. Gosta Leonard         0       3
# 7  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)         1       3
# 8                Nasser, Mrs. Nicholas (Adele Achem)         1       2
# 9                    Sandstrom, Miss. Marguerite Rut         1       3

# %%
pd.concat([df4,df5])
# Out:
#                                                 Name  Survived  Pclass
# 0                            Braund, Mr. Owen Harris         0       3
# 1                             Heikkinen, Miss. Laina         1       3
# 2       Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1
# 3                           Allen, Mr. William Henry         0       3
# 4                                   Moran, Mr. James         0       3
# 5                            McCarthy, Mr. Timothy J         0       1
# 6                     Palsson, Master. Gosta Leonard         0       3
# 7  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)         1       3
# 8                Nasser, Mrs. Nicholas (Adele Achem)         1       2
# 9                    Sandstrom, Miss. Marguerite Rut         1       3

# %%
df6=pd.concat([df4,df5],axis=1)

# %%
df6
# Out:
#                                            Name  Survived  Pclass
# 0                       Braund, Mr. Owen Harris       0.0     3.0  \
# 1                        Heikkinen, Miss. Laina       1.0     3.0
# 2  Futrelle, Mrs. Jacques Heath (Lily May Peel)       1.0     1.0
# 3                      Allen, Mr. William Henry       0.0     3.0
# 4                              Moran, Mr. James       0.0     3.0
# 5                                           NaN       NaN     NaN
# 6                                           NaN       NaN     NaN
# 7                                           NaN       NaN     NaN
# 8                                           NaN       NaN     NaN
# 9                                           NaN       NaN     NaN
#
#                                                 Name  Survived  Pclass
# 0                                                NaN       NaN     NaN
# 1                                                NaN       NaN     NaN
# ...

# %%
df6.fillna("Gaurav")
# Out:
#                                            Name Survived  Pclass
# 0                       Braund, Mr. Owen Harris      0.0     3.0  \
# 1                        Heikkinen, Miss. Laina      1.0     3.0
# 2  Futrelle, Mrs. Jacques Heath (Lily May Peel)      1.0     1.0
# 3                      Allen, Mr. William Henry      0.0     3.0
# 4                              Moran, Mr. James      0.0     3.0
# 5                                        Gaurav   Gaurav  Gaurav
# 6                                        Gaurav   Gaurav  Gaurav
# 7                                        Gaurav   Gaurav  Gaurav
# 8                                        Gaurav   Gaurav  Gaurav
# 9                                        Gaurav   Gaurav  Gaurav
#
#                                                 Name Survived  Pclass
# 0                                             Gaurav   Gaurav  Gaurav
# 1                                             Gaurav   Gaurav  Gaurav
# ...

# %%
df6
# Out:
#                                            Name  Survived  Pclass
# 0                       Braund, Mr. Owen Harris       0.0     3.0  \
# 1                        Heikkinen, Miss. Laina       1.0     3.0
# 2  Futrelle, Mrs. Jacques Heath (Lily May Peel)       1.0     1.0
# 3                      Allen, Mr. William Henry       0.0     3.0
# 4                              Moran, Mr. James       0.0     3.0
# 5                                           NaN       NaN     NaN
# 6                                           NaN       NaN     NaN
# 7                                           NaN       NaN     NaN
# 8                                           NaN       NaN     NaN
# 9                                           NaN       NaN     NaN
#
#                                                 Name  Survived  Pclass
# 0                                                NaN       NaN     NaN
# 1                                                NaN       NaN     NaN
# ...

# %%
data1 = pd.DataFrame({
    "key1":[2,4,8,6,7],
    "key2":[1,4,2,6,3],
    "key3":[7,8,4,2,6]
})

# %%
data1
# Out:
#    key1  key2  key3
# 0     2     1     7
# 1     4     4     8
# 2     8     2     4
# 3     6     6     2
# 4     7     3     6

# %%
data2 = pd.DataFrame({
    "key1":[8,3,9,6,7],
    "key4":[2,6,11,45,3],
    "key5":[4,2,6,41,98]
})

# %%
data2
# Out:
#    key1  key4  key5
# 0     8     2     4
# 1     3     6     2
# 2     9    11     6
# 3     6    45    41
# 4     7     3    98

# %%
data1
# Out:
#    key1  key2  key3
# 0     2     1     7
# 1     4     4     8
# 2     8     2     4
# 3     6     6     2
# 4     7     3     6

# %%
#Inner
pd.merge(data1,data2)
# Out:
#    key1  key2  key3  key4  key5
# 0     8     2     4     2     4
# 1     6     6     2    45    41
# 2     7     3     6     3    98

# %%
#Left
pd.merge(data1,data2,how='left')
# Out:
#    key1  key2  key3  key4  key5
# 0     2     1     7   NaN   NaN
# 1     4     4     8   NaN   NaN
# 2     8     2     4   2.0   4.0
# 3     6     6     2  45.0  41.0
# 4     7     3     6   3.0  98.0

# %%
#right
pd.merge(data1,data2,how='right')
# Out:
#    key1  key2  key3  key4  key5
# 0     8   2.0   4.0     2     4
# 1     3   NaN   NaN     6     2
# 2     9   NaN   NaN    11     6
# 3     6   6.0   2.0    45    41
# 4     7   3.0   6.0     3    98

# %%
#outer
pd.merge(data1,data2,how='outer')
# Out:
#    key1  key2  key3  key4  key5
# 0     2   1.0   7.0   NaN   NaN
# 1     4   4.0   8.0   NaN   NaN
# 2     8   2.0   4.0   2.0   4.0
# 3     6   6.0   2.0  45.0  41.0
# 4     7   3.0   6.0   3.0  98.0
# 5     3   NaN   NaN   6.0   2.0
# 6     9   NaN   NaN  11.0   6.0

# %%
#cross
pd.merge(data1,data2,how='cross')
# Out:
#     key1_x  key2  key3  key1_y  key4  key5
# 0        2     1     7       8     2     4
# 1        2     1     7       3     6     2
# 2        2     1     7       9    11     6
# 3        2     1     7       6    45    41
# 4        2     1     7       7     3    98
# 5        4     4     8       8     2     4
# 6        4     4     8       3     6     2
# 7        4     4     8       9    11     6
# 8        4     4     8       6    45    41
# 9        4     4     8       7     3    98
# 10       8     2     4       8     2     4
# 11       8     2     4       3     6     2
# 12       8     2     4       9    11     6
# 13       8     2     4       6    45    41
# 14       8     2     4       7     3    98
# 15       6     6     2       8     2     4
# 16       6     6     2       3     6     2
# 17       6     6     2       9    11     6
# 18       6     6     2       6    45    41
# 19       6     6     2       7     3    98
# 20       7     3     6       8     2     4
# ...

# %%
pd.merge(data1,data2,how='left',on='key1')
# Out:
#    key1  key2  key3  key4  key5
# 0     2     1     7   NaN   NaN
# 1     4     4     8   NaN   NaN
# 2     8     2     4   2.0   4.0
# 3     6     6     2  45.0  41.0
# 4     7     3     6   3.0  98.0

# %%
pd.merge(data1,data2,how='left',left_on='key2',right_on='key4')
# Out:
#    key1_x  key2  key3  key1_y  key4  key5
# 0       2     1     7     NaN   NaN   NaN
# 1       4     4     8     NaN   NaN   NaN
# 2       8     2     4     8.0   2.0   4.0
# 3       6     6     2     3.0   6.0   2.0
# 4       7     3     6     7.0   3.0  98.0

# %%
data1 = pd.DataFrame({
    "key1":[2,4,8,6,7],
    "key2":[1,4,2,6,3],
    "key3":[7,8,4,2,6]
},index=['a','b','c','d','e']
)
data2 = pd.DataFrame({
    "key11":[8,3,9,6,7],
    "key22":[2,6,11,45,3],
    "key33":[4,2,6,41,98]
},index=['a','b','h','i','j']
)

# %%
data1
# Out:
#    key1  key2  key3
# a     2     1     7
# b     4     4     8
# c     8     2     4
# d     6     6     2
# e     7     3     6

# %%
data2
# Out:
#    key11  key22  key33
# a      8      2      4
# b      3      6      2
# h      9     11      6
# i      6     45     41
# j      7      3     98

# %%
#Indexes are Matching whereas in Merge Columns are Matching
data1.join(data2)
# Out:
#    key1  key2  key3  key11  key22  key33
# a     2     1     7    8.0    2.0    4.0
# b     4     4     8    3.0    6.0    2.0
# c     8     2     4    NaN    NaN    NaN
# d     6     6     2    NaN    NaN    NaN
# e     7     3     6    NaN    NaN    NaN

# %%
data1.join(data2,how='inner')
# Out:
#    key1  key2  key3  key11  key22  key33
# a     2     1     7      8      2      4
# b     4     4     8      3      6      2

# %%
data1.join(data2,how='right')
# Out:
#    key1  key2  key3  key11  key22  key33
# a   2.0   1.0   7.0      8      2      4
# b   4.0   4.0   8.0      3      6      2
# h   NaN   NaN   NaN      9     11      6
# i   NaN   NaN   NaN      6     45     41
# j   NaN   NaN   NaN      7      3     98

# %%
data1.join(data2,how='outer')
# Out:
#    key1  key2  key3  key11  key22  key33
# a   2.0   1.0   7.0    8.0    2.0    4.0
# b   4.0   4.0   8.0    3.0    6.0    2.0
# c   8.0   2.0   4.0    NaN    NaN    NaN
# d   6.0   6.0   2.0    NaN    NaN    NaN
# e   7.0   3.0   6.0    NaN    NaN    NaN
# h   NaN   NaN   NaN    9.0   11.0    6.0
# i   NaN   NaN   NaN    6.0   45.0   41.0
# j   NaN   NaN   NaN    7.0    3.0   98.0

# %%
data1.join(data2,how='cross')
# Out:
#     key1  key2  key3  key11  key22  key33
# 0      2     1     7      8      2      4
# 1      2     1     7      3      6      2
# 2      2     1     7      9     11      6
# 3      2     1     7      6     45     41
# 4      2     1     7      7      3     98
# 5      4     4     8      8      2      4
# 6      4     4     8      3      6      2
# 7      4     4     8      9     11      6
# 8      4     4     8      6     45     41
# 9      4     4     8      7      3     98
# 10     8     2     4      8      2      4
# 11     8     2     4      3      6      2
# 12     8     2     4      9     11      6
# 13     8     2     4      6     45     41
# 14     8     2     4      7      3     98
# 15     6     6     2      8      2      4
# 16     6     6     2      3      6      2
# 17     6     6     2      9     11      6
# 18     6     6     2      6     45     41
# 19     6     6     2      7      3     98
# 20     7     3     6      8      2      4
# ...

# %%
df.head()
# Out:
#                                            Name  Survived  Pclass     Sex
# 0                       Braund, Mr. Owen Harris         0       3    male  \
# 1                        Heikkinen, Miss. Laina         1       3  female
# 2  Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1  female
# 3                      Allen, Mr. William Henry         0       3    male
# 4                              Moran, Mr. James         0       3    male
#
#     Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 2  35.0      1      0            113803  53.1000  C123        S
# 3  35.0      0      0            373450   8.0500   NaN        S
# 4   NaN      0      0            330877   8.4583   NaN        Q

# %%
len(df)
# Out:
# 890

# %%
df['Conversion_Fare']=df['Fare'].apply(lambda x: x*80)

# %%
df
# Out:
#                                              Name  Survived  Pclass     Sex
# 0                         Braund, Mr. Owen Harris         0       3    male  \
# 1                          Heikkinen, Miss. Laina         1       3  female
# 2    Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1  female
# 3                        Allen, Mr. William Henry         0       3    male
# 4                                Moran, Mr. James         0       3    male
# ..                                            ...       ...     ...     ...
# 885                         Montvila, Rev. Juozas         0       2    male
# 886                  Graham, Miss. Margaret Edith         1       1  female
# 887      Johnston, Miss. Catherine Helen "Carrie"         0       3  female
# 888                         Behr, Mr. Karl Howell         1       1    male
# 889                           Dooley, Mr. Patrick         0       3    male
#
# ...

# %%
df['Length_Name']=df['Name'].apply(lambda x: len(x))

# %%
df
# Out:
#                                              Name  Survived  Pclass     Sex
# 0                         Braund, Mr. Owen Harris         0       3    male  \
# 1                          Heikkinen, Miss. Laina         1       3  female
# 2    Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1  female
# 3                        Allen, Mr. William Henry         0       3    male
# 4                                Moran, Mr. James         0       3    male
# ..                                            ...       ...     ...     ...
# 885                         Montvila, Rev. Juozas         0       2    male
# 886                  Graham, Miss. Margaret Edith         1       1  female
# 887      Johnston, Miss. Catherine Helen "Carrie"         0       3  female
# 888                         Behr, Mr. Karl Howell         1       1    male
# 889                           Dooley, Mr. Patrick         0       3    male
#
# ...

# %%
def inr_conv(x):
    return x*80
df['Fare_inr']=df['Fare'].apply(inr_conv)

# %%
df
# Out:
#                                              Name  Survived  Pclass     Sex
# 0                         Braund, Mr. Owen Harris         0       3    male  \
# 1                          Heikkinen, Miss. Laina         1       3  female
# 2    Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1  female
# 3                        Allen, Mr. William Henry         0       3    male
# 4                                Moran, Mr. James         0       3    male
# ..                                            ...       ...     ...     ...
# 885                         Montvila, Rev. Juozas         0       2    male
# 886                  Graham, Miss. Margaret Edith         1       1  female
# 887      Johnston, Miss. Catherine Helen "Carrie"         0       3  female
# 888                         Behr, Mr. Karl Howell         1       1    male
# 889                           Dooley, Mr. Patrick         0       3    male
#
# ...

# %%
def create_flag(x):
    if x<10:
        return "cheap"
    elif x>=10 and x<20:
        return "mid"
    else:
        return "high"

# %%
df['Fare_Category']=df['Fare'].apply(create_flag)

# %%
df
# Out:
#                                              Name  Survived  Pclass     Sex
# 0                         Braund, Mr. Owen Harris         0       3    male  \
# 1                          Heikkinen, Miss. Laina         1       3  female
# 2    Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1  female
# 3                        Allen, Mr. William Henry         0       3    male
# 4                                Moran, Mr. James         0       3    male
# ..                                            ...       ...     ...     ...
# 885                         Montvila, Rev. Juozas         0       2    male
# 886                  Graham, Miss. Margaret Edith         1       1  female
# 887      Johnston, Miss. Catherine Helen "Carrie"         0       3  female
# 888                         Behr, Mr. Karl Howell         1       1    male
# 889                           Dooley, Mr. Patrick         0       3    male
#
# ...
